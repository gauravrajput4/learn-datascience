# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## create a Dataframe

# %%
data={
    'Name':['Akhil','sahil','Warish','Aman'],
    'Age':[21,23,24,18],
    'City':['Kannauj','Abohar','Mau','Kannauj'],
    'salary':[40000,45000,30000,25000]
}

# %%
df1=pd.DataFrame(data)

# %%
df
# Out:
#      Name  Age     City  salary
# 0   Akhil   21  Kannauj   40000
# 1   sahil   23   Abohar   45000
# 2  Warish   24      Mau   30000
# 3    Aman   18  Kannauj   25000

# %%
data_list=[
    ['Akhil',21,'Kannauj',40000],
    ['sahil',23,'Abohar',45000],
    ['Warish',24,'Mau',45000],
    ['Aman',18,'Kannauj',25000]
]
columns=['Name','Age','City','Salary']

# %%
df2=pd.DataFrame(data_list)

# %%
df2=pd.DataFrame(data_list,columns=columns)

# %%
df2
# Out:
#      Name  Age     City  Salary
# 0   Akhil   21  Kannauj   40000
# 1   sahil   23   Abohar   45000
# 2  Warish   24      Mau   45000
# 3    Aman   18  Kannauj   25000

# %% [markdown]
# ## Selection and Indexing of Columns

# %%
df2['Name']
# Out:
# 0     Akhil
# 1     sahil
# 2    Warish
# 3      Aman
# Name: Name, dtype: object

# %%
df2[['Name','City']]
# Out:
#      Name     City
# 0   Akhil  Kannauj
# 1   sahil   Abohar
# 2  Warish      Mau
# 3    Aman  Kannauj

# %% [markdown]
# ## Creating a columns

# %%
df2['Designation']=['Software Developer','Front-end Developer','Back-end Developer','Doctor']

# %%
df2
# Out:
#      Name  Age     City  Salary          Designation
# 0   Akhil   21  Kannauj   40000   Software Developer
# 1   sahil   23   Abohar   45000  Front-end Developer
# 2  Warish   24      Mau   45000   Back-end Developer
# 3    Aman   18  Kannauj   25000               Doctor

# %% [markdown]
# ## Removing or Dropping columns

# %%
df2.drop('Designation',axis=1)
# Out:
#      Name  Age     City  Salary
# 0   Akhil   21  Kannauj   40000
# 1   sahil   23   Abohar   45000
# 2  Warish   24      Mau   45000
# 3    Aman   18  Kannauj   25000

# %%
df2
# Out:
#      Name  Age     City  Salary          Designation
# 0   Akhil   21  Kannauj   40000   Software Developer
# 1   sahil   23   Abohar   45000  Front-end Developer
# 2  Warish   24      Mau   45000   Back-end Developer
# 3    Aman   18  Kannauj   25000               Doctor

# %%
df2.drop('Designation',axis=1,inplace=True)

# %%
df2
# Out:
#      Name  Age     City  Salary
# 0   Akhil   21  Kannauj   40000
# 1   sahil   23   Abohar   45000
# 2  Warish   24      Mau   45000
# 3    Aman   18  Kannauj   25000

# %%
df2.drop(['Age','City'],axis=1)
# Out:
#      Name  Salary
# 0   Akhil   40000
# 1   sahil   45000
# 2  Warish   45000
# 3    Aman   25000

# %%
## Removing Row
df2.drop(3,axis=0)
# Out:
#      Name  Age     City  Salary
# 0   Akhil   21  Kannauj   40000
# 1   sahil   23   Abohar   45000
# 2  Warish   24      Mau   45000

# %% [markdown]
# ### Selecting Rows

# %%
df2.loc[[0,1]]
# Out:
#        0   1        2      3
# 0  Akhil  21  Kannauj  40000
# 1  sahil  23   Abohar  45000

# %%
df2.iloc[0]
# Out:
# 0      Akhil
# 1         21
# 2    Kannauj
# 3      40000
# Name: 0, dtype: object

# %% [markdown]
# ### Selecting Subsets of rows and Columns

# %%
df2
# Out:
#      Name  Age     City  Salary
# 0   Akhil   21  Kannauj   40000
# 1   sahil   23   Abohar   45000
# 2  Warish   24      Mau   45000
# 3    Aman   18  Kannauj   25000

# %%
df2.loc[[0,1]][['City','Salary']]
# Out:
#       City  Salary
# 0  Kannauj   40000
# 1   Abohar   45000

# %%
df2.loc[[2,3]][['Name','Age']]
# Out:
#      Name  Age
# 2  Warish   24
# 3    Aman   18

# %% [markdown]
# ### Conditional Selection

# %%
df2
# Out:
#      Name  Age     City  Salary
# 0   Akhil   21  Kannauj   40000
# 1   sahil   23   Abohar   45000
# 2  Warish   24      Mau   45000
# 3    Aman   18  Kannauj   25000

# %%
# I only want to see those people whose age is above 22

# %%
df2[df2['Age']>22]
# Out:
#      Name  Age    City  Salary
# 1   sahil   23  Abohar   45000
# 2  Warish   24     Mau   45000

# %%
# city must be Abohar
df2[(df2['Age']>22) & (df2['City']=='Abohar')]
# Out:
#     Name  Age    City  Salary
# 1  sahil   23  Abohar   45000
